# %% [markdown]
# # Pandas Lecture Lab Activity

# %% [markdown]
# What is CRUD?

# %%
Create Read Update Delete

# %% [markdown]
# Using pandas import the Module 7 Lecture Lab Activity.csv

# %%
#pip install pandas
import pandas as pd
df = pd.read_csv("orders2.csv")

pd.set_option('display.width', 1000)

# %%
print(df)

# %% [markdown]
# Show the header for the CSV.

# %%
df.head()

# %%
df.tail()

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# Show the first 15 rows of the CSV.

# %%
df.head(15)

# %% [markdown]
# Show the last 7 rows of the CSV.

# %%
df.tail(7)

# %% [markdown]
# Show all the Columns of the CSV.

# %%
df.columns

# %% [markdown]
# Show the specific data types of the CSV.

# %%
df.dtypes

# %% [markdown]
# Show a statistical summary of the CSV.

# %%
df.describe()

# %% [markdown]
# What objects are not included in the statistical summary?
# How can I get the objects that are not included?

# %%
Non numeric data

# %%
# write the code to show me how to get the objects that are not included

# %%
df.describe(include='all')

# %% [markdown]
# Show how to filter the names from the rest of the table?

# %%
df.loc[df["CustomerName"] == "Anna Ivanova"]

# %% [markdown]
# Show me the unique names.

# %%
df.value_counts("CustomerName")

# %% [markdown]
# Show me only the rows that are under $1.00

# %%
#df[df["Price"] < 1]
df[df["Price"] < 50]

# %% [markdown]
# Show only the rows 17 to 37

# %%
df.iloc[17:37]

# %% [markdown]
# Show only the rows that are for Damien.

# %%
df.loc[df["CustomerName"] == "Anna Ivanova"]

# %% [markdown]
# Create a new column names is_candy and make all the rows True

# %%
df['is_candy'] = True
print(df)

# %% [markdown]
# Change the name of the row you created to Candy.

# %%
df = df.rename(columns={'is_candy': 'Candy'})
print(df)

# %% [markdown]
# Write an statement that iterates through the list and finds all the Snicker or snickers (for this I change it to anything that starts with Desk)

# %%
df[df["Product"].str.lower().str.startswith("desk")]

# %% [markdown]
# Using iloc change the 3rd row's candy column to False

# %%
df.iloc[2, 9] = False
print(df)

# %% [markdown]
# pOutput the table to a csv named 'your_last_name_mod7output.csv'

# %%
df.to_csv("roque_mod7output.csv", index=True)

# %% [markdown]
# Drop the candy column permanently

# %%
df = df.drop("Candy", axis=1)
print(df)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity   Price   OrderDate Shipped       Country
# 0      1001        John Smith                 Laptop  Electronics         1  1200.0  2024-06-01     Yes           USA
# 1      1002         Sarah Lee             Headphones  Electronics         2   150.0  2024-06-03      No        Canada
# 2      1003          Ali Khan           Office Chair    Furniture         1   300.0  2024-06-04     Yes           UAE
# 3      1004        Alice Wong              Desk Lamp    Furniture         3    45.0  2024-06-05     Yes     Singapore
# 4      1005     Carlos Mendez               Keyboard  Electronics         2    80.0  2024-06-06      No        Mexico
# 5      1006      Nora Ibrahim               Notebook   Stationery         5     5.0  2024-06-07     Yes           UAE
# 6      1007       Emily Davis          Standing Desk    Furniture         1   450.0  2024-06-08     Yes            UK
# ...

# %% [markdown]
# # Please turn in the completed Juypter Notebook along with your output csv to github. Make sure that I can see the notebook and it is not just the file as this sometimes does not work. A link to the location on the repo should be submitted.
